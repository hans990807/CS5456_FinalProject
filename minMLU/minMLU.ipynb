# %%
# dataFolder = "../data/ATT"
# pathName = "ECMP"
dataFolder = "ATT"
pathName = "SMORE"

# %%
"""
parse topology file
input: topology file
output: [( node1, node2, {'capacity': capacity}),] 
"""
def parseTopology(topology_path):
    topologyFile = open(topology_path)
    count = 0
    edgeList = []
    for line in topologyFile:
        count += 1
        if count == 1:
            continue
        linelist = line.split()
        # print(linelist)
        if len(linelist) <3:
            continue
        edgeList.append((int(linelist[0]), int(linelist[1]), {'capacity': int(linelist[2])}))
        # print(linelist)
    return edgeList
           
topology_path = dataFolder + "/topology.txt"       
edgeList = parseTopology(topology_path)
# print(edgeList)

# %%
"""
extract nodelist from nodes.txt
input: node file path
output: list of node (int)

"""
def extractNodes(nodefile):
    nodeFile = open(nodefile)
    count = 0
    nodeList = []
    for line in nodeFile:
        count += 1
        if count == 1:
            continue
        node = line.strip()[1:]
        nodeList.append(int(node))
        #print (line)
    return nodeList

nodefile = dataFolder + "/nodes.txt"
nodeList = extractNodes(nodefile)

print("the number of nodes: ")
print(len(nodeList))
# Out:
# the number of nodes:
# 25

# %%
"""
construct graph

"""
# add node
import networkx as nx
DG = nx.DiGraph()
DG.add_nodes_from(nodeList)
# add edge
DG.add_edges_from(edgeList)
# print(DG)

# get edges: return a list of edges(tuple)
# DG.edges()

# %%
"""
capacitys: 
{(node1, node2): capacity, }
"""
capacitys = nx.get_edge_attributes(DG,'capacity')
# print(capacitys)

# %%
"""
draw graph
first draw nodes and edges, then add capacity to the edge
"""

import matplotlib.pyplot as plt
pos=nx.spring_layout(DG)
# print(pos)
plt.figure()
# draw nodes
nx.draw_networkx(DG, pos, with_labels=True,node_color='yellow', font_size = 5,node_size=100, width=0.5, linewidths=1)
# draw capacities
nx.draw_networkx_edge_labels(DG, pos, edge_labels=capacitys, font_size=5)
plt.axis('off')
plt.show()

# %%
"""  
parse the demand.txt
input: demand file path
output: max_demand_matrix
        max_demand_matrix[x][y] means max demand from node x to node y
        {
            1:{ 1:float, 2:float, 3:,..., 25:float}
            2:
            3:
            ..
            25:
        }
"""

def parseDemand(demandFile): 
    demandFile = open(demandFile)
    demand_matrix = {}
    max_demand_matrix = {}
    node_amount = len(nodeList)

    # extract the demand list from x to y
    for line in demandFile:
        row = [float(x) for x in line.split()]
        for index, demand in enumerate(row):
            from_node = int(index/node_amount) + 1
            to_node = index%node_amount +1
            if from_node not in demand_matrix:
                demand_matrix[from_node] = {}
                max_demand_matrix[from_node] = {}
            if to_node not in demand_matrix[from_node]:
                demand_matrix[from_node][to_node] = []
            demand_matrix[from_node][to_node].append(demand)
    
    # just want to max demand from x to y
    for from_node in demand_matrix:
        for to_node in demand_matrix:
            max_demand = max(demand_matrix[from_node][to_node])
            max_demand_matrix[from_node][to_node] = max_demand
    return max_demand_matrix


demandFile = dataFolder + "/demand.txt"
max_demand_matrix = parseDemand(demandFile)
# print(max_demand_matrix)

# %%
"""
parse the path file
input: path file path
output: list of all path
"""
def extractAllPaths(pathFile): 
    pathFile = open(pathFile)
    pathCollection = []
    for line in pathFile:
        line = line.strip()
        if len(line) == 0: continue
        if line[0] == "h": continue
        line = line.split("@")[0]
        path = []
        p = 0
        while p < len(line):
            if line[p] == "s":
                # print(line[p])
                node_str = ""
                p += 1
                # print(line[p])
                while line[p].isdigit():
                    # print(line[p])
                    node_str += line[p]
                    p += 1

                if path and path[-1] == int(node_str):
                    pass
                else:
                    path.append(int(node_str))
            p += 1
        # print(path)
        edgesInPath = []
        for i in range(1, len(path)):
            edgesInPath.append((path[i-1], path[i]))
        pathCollection.append(edgesInPath)
    return pathCollection

pathFile = dataFolder + "/paths/" + pathName
pathCollection = extractAllPaths(pathFile)
# print(pathCollection)

# %%
""" 
find shortest path (the path contain least edges) for every (source, destination)
input: pathCollection: list of all path
output: {(source_node, destination_node): [edges]}
        for example: {(10, 19):[(10, 13), (13, 17), (17, 19)], }

"""
def findShortestPath(pathCollection):
    shortestPathDic = {}
    for path in pathCollection:
        key = (path[0][0], path[len(path)-1][1])
        if key not in shortestPathDic:
            shortestPathDic[key] = path
        else:
            if len(path) < len(shortestPathDic[key]):
                shortestPathDic[key] = path
    return shortestPathDic

shortestPathDic = findShortestPath(pathCollection)
# check output
for item in shortestPathDic.items():
    print(item)
# Out:
# ((8, 9), [(8, 9)])
# ((8, 2), [(8, 3), (3, 2)])
# ((8, 3), [(8, 3)])
# ((8, 25), [(8, 3), (3, 6), (6, 25)])
# ((8, 1), [(8, 3), (3, 6), (6, 1)])
# ((8, 6), [(8, 3), (3, 6)])
# ((8, 7), [(8, 5), (5, 7)])
# ((8, 4), [(8, 5), (5, 4)])
# ((8, 5), [(8, 5)])
# ((8, 23), [(8, 13), (13, 22), (22, 23)])
# ((8, 22), [(8, 13), (13, 22)])
# ((8, 21), [(8, 13), (13, 17), (17, 21)])
# ((8, 20), [(8, 13), (13, 17), (17, 20)])
# ((8, 19), [(8, 13), (13, 17), (17, 19)])
# ((8, 18), [(8, 13), (13, 17), (17, 18)])
# ((8, 13), [(8, 13)])
# ((8, 12), [(8, 13), (13, 12)])
# ((8, 11), [(8, 13), (13, 11)])
# ((8, 10), [(8, 13), (13, 10)])
# ((8, 17), [(8, 13), (13, 17)])
# ((8, 16), [(8, 13), (13, 16)])
# ((8, 15), [(8, 13), (13, 15)])
# ((8, 14), [(8, 5), (5, 14)])
# ((8, 24), [(8, 13), (13, 22), (22, 24)])
# ((9, 8), [(9, 8)])
# ((9, 2), [(9, 2)])
# ((9, 3), [(9, 3)])
# ((9, 25), [(9, 2), (2, 25)])
# ((9, 1), [(9, 2), (2, 6), (6, 1)])
# ((9, 6), [(9, 2), (2, 6)])
# ((9, 7), [(9, 5), (5, 7)])
# ((9, 4), [(9, 5), (5, 4)])
# ((9, 5), [(9, 5)])
# ((9, 23), [(9, 22), (22, 23)])
# ((9, 22), [(9, 22)])
# ((9, 21), [(9, 2), (2, 21)])
# ((9, 20), [(9, 2), (2, 20)])
# ((9, 19), [(9, 2), (2, 20), (20, 19)])
# ((9, 18), [(9, 2), (2, 17), (17, 18)])
# ((9, 13), [(9, 13)])
# ((9, 12), [(9, 13), (13, 12)])
# ((9, 11), [(9, 13), (13, 11)])
# ((9, 10), [(9, 13), (13, 10)])
# ((9, 17), [(9, 2), (2, 17)])
# ((9, 16), [(9, 16)])
# ((9, 15), [(9, 2), (2, 15)])
# ((9, 14), [(9, 5), (5, 14)])
# ((9, 24), [(9, 22), (22, 24)])
# ((2, 8), [(2, 3), (3, 8)])
# ((2, 9), [(2, 9)])
# ((2, 3), [(2, 3)])
# ((2, 25), [(2, 25)])
# ((2, 1), [(2, 6), (6, 1)])
# ((2, 6), [(2, 6)])
# ((2, 7), [(2, 6), (6, 7)])
# ((2, 4), [(2, 6), (6, 7), (7, 4)])
# ((2, 5), [(2, 9), (9, 5)])
# ((2, 23), [(2, 17), (17, 22), (22, 23)])
# ((2, 22), [(2, 17), (17, 22)])
# ((2, 21), [(2, 21)])
# ((2, 20), [(2, 20)])
# ((2, 19), [(2, 17), (17, 19)])
# ((2, 18), [(2, 17), (17, 18)])
# ((2, 13), [(2, 17), (17, 13)])
# ((2, 12), [(2, 17), (17, 13), (13, 12)])
# ((2, 11), [(2, 17), (17, 13), (13, 11)])
# ((2, 10), [(2, 17), (17, 13), (13, 10)])
# ((2, 17), [(2, 17)])
# ((2, 16), [(2, 16)])
# ((2, 15), [(2, 15)])
# ((2, 14), [(2, 9), (9, 5), (5, 14)])
# ((2, 24), [(2, 17), (17, 22), (22, 24)])
# ((3, 8), [(3, 8)])
# ((3, 9), [(3, 9)])
# ((3, 2), [(3, 2)])
# ((3, 25), [(3, 6), (6, 25)])
# ((3, 1), [(3, 6), (6, 1)])
# ((3, 6), [(3, 6)])
# ((3, 7), [(3, 6), (6, 7)])
# ((3, 4), [(3, 6), (6, 7), (7, 4)])
# ((3, 5), [(3, 8), (8, 5)])
# ((3, 23), [(3, 9), (9, 22), (22, 23)])
# ((3, 22), [(3, 9), (9, 22)])
# ((3, 21), [(3, 2), (2, 21)])
# ((3, 20), [(3, 2), (2, 20)])
# ((3, 19), [(3, 2), (2, 20), (20, 19)])
# ((3, 18), [(3, 2), (2, 17), (17, 18)])
# ((3, 13), [(3, 8), (8, 13)])
# ((3, 12), [(3, 8), (8, 13), (13, 12)])
# ((3, 11), [(3, 8), (8, 13), (13, 11)])
# ((3, 10), [(3, 8), (8, 13), (13, 10)])
# ((3, 17), [(3, 2), (2, 17)])
# ((3, 16), [(3, 2), (2, 16)])
# ((3, 15), [(3, 2), (2, 15)])
# ((3, 14), [(3, 8), (8, 5), (5, 14)])
# ((3, 24), [(3, 9), (9, 22), (22, 24)])
# ((25, 8), [(25, 6), (6, 3), (3, 8)])
# ((25, 9), [(25, 2), (2, 9)])
# ((25, 2), [(25, 2)])
# ((25, 3), [(25, 6), (6, 3)])
# ((25, 1), [(25, 1)])
# ((25, 6), [(25, 6)])
# ((25, 7), [(25, 7)])
# ((25, 4), [(25, 7), (7, 4)])
# ((25, 5), [(25, 7), (7, 5)])
# ((25, 23), [(25, 2), (2, 17), (17, 22), (22, 23)])
# ((25, 22), [(25, 2), (2, 17), (17, 22)])
# ((25, 21), [(25, 2), (2, 21)])
# ((25, 20), [(25, 2), (2, 20)])
# ((25, 19), [(25, 2), (2, 17), (17, 19)])
# ((25, 18), [(25, 2), (2, 17), (17, 18)])
# ((25, 13), [(25, 2), (2, 17), (17, 13)])
# ((25, 12), [(25, 2), (2, 16), (16, 13), (13, 12)])
# ((25, 11), [(25, 2), (2, 17), (17, 13), (13, 11)])
# ((25, 10), [(25, 2), (2, 17), (17, 13), (13, 10)])
# ((25, 17), [(25, 2), (2, 17)])
# ((25, 16), [(25, 2), (2, 16)])
# ((25, 15), [(25, 2), (2, 15)])
# ((25, 14), [(25, 7), (7, 5), (5, 14)])
# ((25, 24), [(25, 2), (2, 17), (17, 22), (22, 24)])
# ((1, 8), [(1, 6), (6, 3), (3, 8)])
# ((1, 9), [(1, 6), (6, 2), (2, 9)])
# ((1, 2), [(1, 6), (6, 2)])
# ((1, 3), [(1, 6), (6, 3)])
# ((1, 25), [(1, 25)])
# ((1, 6), [(1, 6)])
# ((1, 7), [(1, 6), (6, 7)])
# ((1, 4), [(1, 6), (6, 7), (7, 4)])
# ((1, 5), [(1, 6), (6, 7), (7, 5)])
# ((1, 23), [(1, 6), (6, 2), (2, 17), (17, 22), (22, 23)])
# ((1, 22), [(1, 6), (6, 2), (2, 9), (9, 22)])
# ((1, 21), [(1, 6), (6, 2), (2, 21)])
# ((1, 20), [(1, 6), (6, 2), (2, 20)])
# ((1, 19), [(1, 6), (6, 2), (2, 20), (20, 19)])
# ((1, 18), [(1, 6), (6, 2), (2, 17), (17, 18)])
# ((1, 13), [(1, 6), (6, 2), (2, 16), (16, 13)])
# ((1, 12), [(1, 6), (6, 2), (2, 16), (16, 13), (13, 12)])
# ((1, 11), [(1, 6), (6, 3), (3, 8), (8, 13), (13, 11)])
# ((1, 10), [(1, 6), (6, 2), (2, 16), (16, 13), (13, 10)])
# ((1, 17), [(1, 6), (6, 2), (2, 17)])
# ((1, 16), [(1, 6), (6, 2), (2, 16)])
# ((1, 15), [(1, 6), (6, 2), (2, 15)])
# ((1, 14), [(1, 6), (6, 7), (7, 5), (5, 14)])
# ((1, 24), [(1, 6), (6, 3), (3, 9), (9, 22), (22, 24)])
# ((6, 8), [(6, 3), (3, 8)])
# ((6, 9), [(6, 2), (2, 9)])
# ((6, 2), [(6, 2)])
# ((6, 3), [(6, 3)])
# ((6, 25), [(6, 25)])
# ((6, 1), [(6, 1)])
# ((6, 7), [(6, 7)])
# ((6, 4), [(6, 7), (7, 4)])
# ((6, 5), [(6, 7), (7, 5)])
# ((6, 23), [(6, 2), (2, 17), (17, 22), (22, 23)])
# ((6, 22), [(6, 2), (2, 17), (17, 22)])
# ((6, 21), [(6, 2), (2, 21)])
# ((6, 20), [(6, 2), (2, 20)])
# ((6, 19), [(6, 2), (2, 20), (20, 19)])
# ((6, 18), [(6, 2), (2, 17), (17, 18)])
# ((6, 13), [(6, 2), (2, 16), (16, 13)])
# ((4, 24), [(4, 5), (5, 13), (13, 22), (22, 24)])
# ((5, 8), [(5, 8)])
# ((5, 9), [(5, 9)])
# ((5, 2), [(5, 9), (9, 2)])
# ((5, 3), [(5, 8), (8, 3)])
# ((5, 25), [(5, 7), (7, 25)])
# ((5, 1), [(5, 7), (7, 6), (6, 1)])
# ((5, 6), [(5, 7), (7, 6)])
# ((5, 7), [(5, 7)])
# ((5, 4), [(5, 4)])
# ((5, 23), [(5, 13), (13, 22), (22, 23)])
# ((5, 22), [(5, 13), (13, 22)])
# ((5, 21), [(5, 13), (13, 22), (22, 21)])
# ((5, 20), [(5, 13), (13, 17), (17, 20)])
# ((5, 19), [(5, 13), (13, 17), (17, 19)])
# ((5, 18), [(5, 13), (13, 17), (17, 18)])
# ((5, 13), [(5, 13)])
# ((5, 12), [(5, 13), (13, 12)])
# ((5, 11), [(5, 13), (13, 11)])
# ((5, 10), [(5, 13), (13, 10)])
# ((5, 17), [(5, 13), (13, 17)])
# ((5, 16), [(5, 13), (13, 16)])
# ((5, 15), [(5, 13), (13, 15)])
# ((5, 14), [(5, 14)])
# ((5, 24), [(5, 13), (13, 12), (12, 24)])
# ((23, 8), [(23, 22), (22, 13), (13, 8)])
# ((23, 9), [(23, 22), (22, 9)])
# ((23, 2), [(23, 22), (22, 17), (17, 2)])
# ((23, 3), [(23, 22), (22, 9), (9, 3)])
# ((23, 25), [(23, 22), (22, 17), (17, 2), (2, 25)])
# ((23, 1), [(23, 22), (22, 17), (17, 2), (2, 6), (6, 1)])
# ((23, 6), [(23, 22), (22, 17), (17, 2), (2, 6)])
# ((23, 7), [(23, 22), (22, 13), (13, 5), (5, 7)])
# ((23, 4), [(23, 22), (22, 13), (13, 5), (5, 4)])
# ((23, 5), [(23, 22), (22, 13), (13, 5)])
# ((23, 22), [(23, 22)])
# ((23, 21), [(23, 22), (22, 21)])
# ((23, 20), [(23, 22), (22, 17), (17, 20)])
# ((23, 19), [(23, 22), (22, 17), (17, 19)])
# ((23, 18), [(23, 22), (22, 17), (17, 18)])
# ((23, 13), [(23, 22), (22, 13)])
# ((23, 12), [(23, 24), (24, 12)])
# ((23, 11), [(23, 22), (22, 13), (13, 11)])
# ((23, 10), [(23, 22), (22, 13), (13, 10)])
# ((23, 17), [(23, 22), (22, 17)])
# ((23, 16), [(23, 22), (22, 9), (9, 16)])
# ((23, 15), [(23, 22), (22, 17), (17, 15)])
# ((23, 14), [(23, 22), (22, 13), (13, 10), (10, 14)])
# ((23, 24), [(23, 24)])
# ((22, 8), [(22, 13), (13, 8)])
# ((22, 9), [(22, 9)])
# ((22, 2), [(22, 17), (17, 2)])
# ((22, 3), [(22, 9), (9, 3)])
# ((22, 25), [(22, 17), (17, 2), (2, 25)])
# ((22, 1), [(22, 17), (17, 2), (2, 25), (25, 1)])
# ((22, 6), [(22, 17), (17, 2), (2, 6)])
# ((22, 7), [(22, 13), (13, 5), (5, 7)])
# ((22, 4), [(22, 13), (13, 5), (5, 4)])
# ((22, 5), [(22, 13), (13, 5)])
# ((19, 9), [(19, 17), (17, 13), (13, 9)])
# ((19, 2), [(19, 17), (17, 2)])
# ((19, 3), [(19, 20), (20, 2), (2, 3)])
# ((19, 25), [(19, 17), (17, 2), (2, 25)])
# ((19, 1), [(19, 17), (17, 2), (2, 25), (25, 1)])
# ((19, 6), [(19, 20), (20, 2), (2, 6)])
# ((19, 7), [(19, 17), (17, 2), (2, 25), (25, 7)])
# ((19, 4), [(19, 17), (17, 13), (13, 5), (5, 4)])
# ((19, 5), [(19, 17), (17, 13), (13, 5)])
# ((19, 23), [(19, 17), (17, 22), (22, 23)])
# ((19, 22), [(19, 17), (17, 22)])
# ((19, 21), [(19, 17), (17, 21)])
# ((19, 20), [(19, 20)])
# ((19, 18), [(19, 17), (17, 18)])
# ((19, 13), [(19, 17), (17, 13)])
# ((19, 12), [(19, 17), (17, 13), (13, 12)])
# ((19, 11), [(19, 17), (17, 13), (13, 11)])
# ((19, 10), [(19, 17), (17, 13), (13, 10)])
# ((19, 17), [(19, 17)])
# ((19, 16), [(19, 17), (17, 16)])
# ((19, 15), [(19, 17), (17, 15)])
# ((19, 14), [(19, 17), (17, 13), (13, 11), (11, 14)])
# ((19, 24), [(19, 17), (17, 22), (22, 24)])
# ((18, 8), [(18, 17), (17, 13), (13, 8)])
# ((18, 9), [(18, 17), (17, 2), (2, 9)])
# ((18, 2), [(18, 17), (17, 2)])
# ((18, 3), [(18, 17), (17, 2), (2, 3)])
# ((18, 25), [(18, 17), (17, 2), (2, 25)])
# ((18, 1), [(18, 17), (17, 2), (2, 6), (6, 1)])
# ((18, 6), [(18, 17), (17, 2), (2, 6)])
# ((18, 7), [(18, 17), (17, 2), (2, 6), (6, 7)])
# ((18, 4), [(18, 17), (17, 13), (13, 5), (5, 4)])
# ((18, 5), [(18, 17), (17, 13), (13, 5)])
# ((18, 23), [(18, 17), (17, 22), (22, 23)])
# ((18, 22), [(18, 17), (17, 22)])
# ((18, 21), [(18, 21)])
# ((18, 20), [(18, 17), (17, 20)])
# ((18, 19), [(18, 17), (17, 19)])
# ((18, 13), [(18, 17), (17, 13)])
# ((18, 12), [(18, 17), (17, 13), (13, 12)])
# ((18, 11), [(18, 17), (17, 13), (13, 11)])
# ((18, 10), [(18, 17), (17, 13), (13, 10)])
# ((18, 17), [(18, 17)])
# ((18, 16), [(18, 17), (17, 16)])
# ((18, 15), [(18, 17), (17, 15)])
# ((18, 14), [(18, 17), (17, 13), (13, 11), (11, 14)])
# ((18, 24), [(18, 17), (17, 22), (22, 24)])
# ((13, 8), [(13, 8)])
# ((13, 9), [(13, 9)])
# ((13, 2), [(13, 17), (17, 2)])
# ((13, 3), [(13, 8), (8, 3)])
# ((13, 25), [(13, 17), (17, 2), (2, 25)])
# ((13, 1), [(13, 8), (8, 3), (3, 6), (6, 1)])
# ((13, 6), [(13, 8), (8, 3), (3, 6)])
# ((13, 7), [(13, 5), (5, 7)])
# ((13, 4), [(13, 5), (5, 4)])
# ((13, 5), [(13, 5)])
# ((13, 23), [(13, 22), (22, 23)])
# ((13, 22), [(13, 22)])
# ((13, 21), [(13, 22), (22, 21)])
# ((13, 20), [(13, 17), (17, 20)])
# ((13, 19), [(13, 17), (17, 19)])
# ((13, 18), [(13, 17), (17, 18)])
# ((13, 12), [(13, 12)])
# ((13, 11), [(13, 11)])
# ((13, 10), [(13, 10)])
# ((13, 17), [(13, 17)])
# ((13, 16), [(13, 16)])
# ((13, 15), [(13, 15)])
# ((13, 14), [(13, 11), (11, 14)])
# ((13, 24), [(13, 22), (22, 24)])
# ((12, 8), [(12, 13), (13, 8)])
# ((12, 9), [(12, 13), (13, 9)])
# ((12, 2), [(12, 13), (13, 17), (17, 2)])
# ((12, 3), [(12, 13), (13, 8), (8, 3)])
# ((12, 25), [(12, 13), (13, 16), (16, 2), (2, 25)])
# ((12, 1), [(12, 13), (13, 8), (8, 3), (3, 6), (6, 1)])
# ((12, 6), [(12, 13), (13, 8), (8, 3), (3, 6)])
# ((12, 7), [(12, 13), (13, 5), (5, 7)])
# ((12, 4), [(12, 13), (13, 5), (5, 4)])
# ((12, 5), [(12, 13), (13, 5)])
# ((12, 23), [(12, 24), (24, 23)])
# ((12, 22), [(12, 13), (13, 22)])
# ((12, 21), [(12, 13), (13, 17), (17, 21)])
# ((12, 20), [(12, 13), (13, 17), (17, 20)])
# ((12, 19), [(12, 13), (13, 17), (17, 19)])
# ((12, 18), [(12, 13), (13, 17), (17, 18)])
# ((12, 13), [(12, 13)])
# ((12, 11), [(12, 11)])
# ((12, 10), [(12, 13), (13, 10)])
# ((12, 17), [(12, 13), (13, 17)])
# ((12, 16), [(12, 13), (13, 16)])
# ((12, 15), [(12, 13), (13, 15)])
# ((12, 14), [(12, 11), (11, 14)])
# ((12, 24), [(12, 24)])
# ((11, 8), [(11, 13), (13, 8)])
# ((11, 9), [(11, 13), (13, 9)])
# ((11, 2), [(11, 13), (13, 17), (17, 2)])
# ((11, 3), [(11, 13), (13, 8), (8, 3)])
# ((11, 25), [(11, 13), (13, 17), (17, 2), (2, 25)])
# ((11, 1), [(11, 13), (13, 8), (8, 3), (3, 6), (6, 1)])
# ((11, 6), [(11, 13), (13, 8), (8, 3), (3, 6)])
# ((11, 7), [(11, 13), (13, 5), (5, 7)])
# ((11, 4), [(11, 13), (13, 5), (5, 4)])
# ((11, 5), [(11, 13), (13, 5)])
# ((11, 23), [(11, 13), (13, 22), (22, 23)])
# ((11, 22), [(11, 13), (13, 22)])
# ((11, 21), [(11, 13), (13, 17), (17, 21)])
# ((11, 20), [(11, 13), (13, 17), (17, 20)])
# ((11, 19), [(11, 13), (13, 17), (17, 19)])
# ((11, 18), [(11, 13), (13, 17), (17, 18)])
# ((11, 13), [(11, 13)])
# ((11, 12), [(11, 12)])
# ((11, 10), [(11, 10)])
# ((11, 17), [(11, 13), (13, 17)])
# ((11, 16), [(11, 13), (13, 16)])
# ((11, 15), [(11, 13), (13, 15)])
# ((11, 14), [(11, 14)])
# ((11, 24), [(11, 12), (12, 24)])
# ((24, 25), [(24, 22), (22, 17), (17, 2), (2, 25)])
# ((24, 1), [(24, 22), (22, 17), (17, 2), (2, 25), (25, 1)])
# ((24, 6), [(24, 22), (22, 17), (17, 2), (2, 6)])
# ((24, 7), [(24, 22), (22, 13), (13, 5), (5, 7)])
# ((24, 4), [(24, 22), (22, 13), (13, 5), (5, 4)])
# ((24, 5), [(24, 22), (22, 9), (9, 5)])
# ((24, 23), [(24, 23)])
# ((24, 22), [(24, 22)])
# ((24, 21), [(24, 22), (22, 21)])
# ((24, 20), [(24, 22), (22, 13), (13, 17), (17, 20)])
# ((24, 19), [(24, 22), (22, 17), (17, 19)])
# ((24, 18), [(24, 22), (22, 17), (17, 18)])
# ((24, 13), [(24, 22), (22, 13)])
# ((24, 12), [(24, 12)])
# ((24, 11), [(24, 12), (12, 11)])
# ((24, 10), [(24, 22), (22, 13), (13, 10)])
# ((24, 17), [(24, 22), (22, 17)])
# ((24, 16), [(24, 22), (22, 9), (9, 16)])
# ((24, 15), [(24, 22), (22, 17), (17, 15)])
# ((24, 14), [(24, 12), (12, 11), (11, 14)])

# %%
""" 
find all paths that an edge belongs to
input: shortestPathDic: {(source_node, destination_node): [edges]}
output: edges_belongsto_paths: {(node1, node2): [(s1, d1), (s2, d2),], }
for example:
  {(8, 5): [(8, 7), (8, 4), (8, 5), (8, 14), (3, 5), (3, 14), }
"""

def findEdgesBelongs(shortestPathDic):
    edges_belongsto_paths = {}
    for path, edgeList in shortestPathDic.items():
        for edge in edgeList:
            if edge not in edges_belongsto_paths and (edge[1], edge[0]) not in edges_belongsto_paths:
                edges_belongsto_paths[edge] = [path]
            elif edge in edges_belongsto_paths:
                edges_belongsto_paths[edge].append(path)
            else: # (edge[1], edge[0]) in 
                edges_belongsto_paths[(edge[1], edge[0])].append(path)
    return edges_belongsto_paths

edges_belongsto_paths = findEdgesBelongs(shortestPathDic)
# check output:
for item in edges_belongsto_paths.items():
    print(item)
# Out:
# ((8, 9), [(8, 9), (9, 8)])
# ((8, 3), [(8, 2), (8, 3), (8, 25), (8, 1), (8, 6), (2, 8), (3, 8), (3, 5), (3, 13), (3, 12), (3, 11), (3, 10), (3, 14), (25, 8), (1, 8), (1, 11), (6, 8), (6, 11), (5, 3), (21, 8), (20, 8), (13, 3), (13, 1), (13, 6), (12, 3), (12, 1), (12, 6), (11, 3), (11, 1), (11, 6), (10, 3), (10, 1), (10, 6), (14, 3)])
# ((3, 2), [(8, 2), (2, 8), (2, 3), (3, 2), (3, 21), (3, 20), (3, 19), (3, 18), (3, 17), (3, 16), (3, 15), (21, 8), (21, 3), (20, 8), (20, 3), (19, 3), (18, 3), (17, 3), (16, 3), (15, 3)])
# ((3, 6), [(8, 25), (8, 1), (8, 6), (3, 25), (3, 1), (3, 6), (3, 7), (3, 4), (25, 8), (25, 3), (1, 8), (1, 3), (1, 11), (1, 24), (6, 8), (6, 3), (6, 11), (7, 3), (4, 3), (13, 1), (13, 6), (12, 1), (12, 6), (11, 1), (11, 6), (10, 1), (10, 6)])
# ((5, 13), [(7, 23), (7, 22), (7, 13), (7, 12), (7, 11), (7, 10), (7, 24), (4, 23), (4, 22), (4, 19), (4, 18), (4, 13), (4, 12), (4, 11), (4, 10), (4, 17), (4, 15), (4, 24), (5, 23), (5, 22), (5, 21), (5, 20), (5, 19), (5, 18), (5, 13), (5, 12), (5, 11), (5, 10), (5, 17), (5, 16), (5, 15), (5, 24), (23, 7), (23, 4), (23, 5), (22, 7), (22, 4), (22, 5), (19, 4), (19, 5), (18, 4), (18, 5), (13, 7), (13, 4), (13, 5), (12, 7), (12, 4), (12, 5), (11, 7), (11, 4), (11, 5), (10, 7), (10, 4), (10, 5), (17, 4), (17, 5), (16, 5), (15, 4), (15, 5), (24, 7), (24, 4)])
# ((22, 21), [(5, 21), (23, 21), (22, 21), (21, 23), (21, 22), (21, 13), (21, 12), (21, 10), (21, 24), (13, 21), (10, 21), (24, 21)])
# ((12, 24), [(5, 24), (23, 12), (21, 12), (12, 23), (12, 24), (11, 24), (16, 24), (15, 24), (14, 23), (14, 24), (24, 12), (24, 11), (24, 14)])
# ((23, 24), [(23, 12), (23, 24), (12, 23), (14, 23), (24, 23)])
# ((17, 15), [(23, 15), (19, 15), (18, 15), (17, 15), (15, 23), (15, 19), (15, 18), (15, 17), (24, 15)])
# ((10, 14), [(23, 14), (10, 14), (14, 21), (14, 10)])
# ((11, 14), [(22, 14), (19, 14), (18, 14), (13, 14), (12, 14), (11, 14), (17, 14), (16, 14), (15, 14), (14, 23), (14, 22), (14, 20), (14, 19), (14, 18), (14, 13), (14, 12), (14, 11), (14, 17), (14, 16), (14, 15), (14, 24), (24, 14)])
# ((21, 18), [(21, 18), (18, 21)])
# ((21, 15), [(21, 15), (15, 21)])
# ((17, 16), [(19, 16), (18, 16), (17, 16), (16, 19), (16, 18), (16, 17)])
# ((12, 11), [(12, 11), (12, 14), (11, 12), (11, 24), (14, 23), (14, 12), (14, 24), (24, 11), (24, 14)])
# ((11, 10), [(11, 10), (10, 11)])
# ((16, 15), [(16, 15), (15, 16)])

# %%
""" 
find path and its max demand
input: shortestPathDic, use the path
output: {(source, destination): int(demand)}
"""
def findPathDemand(shortestPathDic):
    path_demands_dic = {}
    for path in shortestPathDic:
        path_demands_dic[path] = int(max_demand_matrix[path[0]][path[1]])
    return path_demands_dic

path_demands_dic = findPathDemand(shortestPathDic)
# check output:
# for item in path_demands_dic.items():
#     print(item)

# %%
import gurobipy as gp
from gurobipy import GRB
import time

start_time = time.time()

# path,demands = gp.multidict({
#     (1,2):100,
#     (2,3):200,
#     (1,3):300})
path,demands = gp.multidict(path_demands_dic)

# edge: all path (s, d) contains edge
# edges = {
#     (1,2):[(1,2),(1,3)],
#     (2,3):[(2,3),(1,3)]}
edges = edges_belongsto_paths

# {(node1, node2): capacity}
# capacity = {
#     (1,2):400,
#     (2,3):500}
capacity = capacitys

m = gp.Model('te')

#create variable
flow = m.addVars(path,name = "flow")
maxMLU = m.addVar()


# first argument is the expression
# second argument is the index of the objective
# third argument defines the priority. (Higher priority means this objective will be solved first.) 
#set objective
m.setObjectiveN(flow.sum('*'), 0, 1, weight=1000)
m.setObjectiveN(maxMLU*(-1), 1, 0, weight=1)
m.ModelSense = GRB.MAXIMIZE


#add constraint: sum of flow on each edge <= capcity
for edge_key,edge_value in edges.items():
    m.addConstr( sum(flow[p] for p in edge_value) <= capacity[edge_key],"cap")
    m.addConstr( sum(flow[p] for p in edge_value)/capacity[edge_key] <= maxMLU,"cap")
   
    # m.addConstr(maxMLU <= capacity[edge_key])
    # m.addConstr(sum(flow[p] for p in edge_value)/ capacity[edge_key] < 1, "mlu")


#add constraint: flow[p] <= demand
m.addConstrs((flow[p]<= demands[p] for p in path),"dem")


# run
m.optimize()

if m.Status == GRB.OPTIMAL:
    solution = m.getAttr('X',flow)
    # check output
    for f in path:
        print(solution[f])

print("The run time is --- %s seconds ---" % (time.time() - start_time))
# Out:
# Restricted license - for non-production use only - expires 2024-10-28
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1280P, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 824 rows, 601 columns and 3580 nonzeros
# Model fingerprint: 0x0a08cabb
# Variable types: 601 continuous, 0 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [8e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 1e+06]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 2 objectives ...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve ...
# ---------------------------------------------------------------------------
#
# Presolve removed 698 rows and 0 columns
# Presolved: 126 rows and 601 columns
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 1 () ...
# ---------------------------------------------------------------------------
#
# Presolve removed 116 rows and 573 columns
# Presolve time: 0.02s
# Presolved: 10 rows, 28 columns, 54 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8436378e+10   5.758226e+05   0.000000e+00      0s
#        9    1.8053174e+10   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.805317400e+10
# ---------------------------------------------------------------------------
#
# Multi-objectives: optimize objective 2 () ...
# ---------------------------------------------------------------------------
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective -1.000000000e+00
#
# ---------------------------------------------------------------------------
# Multi-objectives: solved in 0.04 seconds (0.00 work units), solution count 1
#
# 1434.0
# 2103.0
# 10685.0
# 6890.0
# 3590.0
# 5854.0
# 4507.0
# 2779.0
# 1973.0
# 758.0
# 1675.0
# 6498.0
# 8188.0
# 1357.0
# 4248.0
# 760.0
# 35677.0
# 11872.0
# 3935.0
# 1421.0
# 12434.0
# 4170.0
# 0.0
# 26532.0
# 23952.0
# 5491.0
# 25542.0
# 17883.0
# 9024.0
# 15107.0
# 10645.0
# 6528.0
# 5327.0
# 2123.0
# 4667.0
# 16410.0
# 21274.0
# 3224.0
# 11171.0
# 2097.0
# 92899.0
# 30476.0
# 10036.0
# 3700.0
# 31551.0
# 10747.0
# 0.0
# 66950.0
# 6581.0
# 1032.0
# 8942.0
# 6259.0
# 2719.0
# 4194.0
# 3177.0
# 2179.0
# 1468.0
# 601.0
# 1587.0
# 5014.0
# 6803.0
# 979.0
# 3384.0
# 611.0
# 31937.0
# 10573.0
# 2820.0
# 1065.0
# 10151.0
# 3477.0
# 0.0
# 19477.0
# 1144.0
# 164.0
# 310.0
# 1003.0
# 481.0
# 786.0
# 606.0
# 386.0
# 271.0
# 98.0
# 265.0
# 969.0
# 1090.0
# 159.0
# 599.0
# 130.0
# 5117.0
# 1694.0
# 484.0
# 178.0
# 1876.0
# 674.0
# 0.0
# 3193.0
# 5550.0
# 868.0
# 1593.0
# 7302.0
# 2488.0
# 3658.0
# 2629.0
# 2035.0
# 1279.0
# 546.0
# 1334.0
# 5221.0
# 6110.0
# 962.0
# 3749.0
# 620.0
# 29939.0
# 10926.0
# 2531.0
# 7535.0
# 3092.0
# 32620.0
# 11553.0
# 52308.0
# 39520.0
# 5225.0
# 8833.0
# 44435.0
# 32999.0
# 16037.0
# 22668.0
# 17452.0
# 11559.0
# 7283.0
# 3389.0
# 7214.0
# 28382.0
# 42088.0
# 5855.0
# 20378.0
# 3162.0
# 159342.0
# 52281.0
# 17070.0
# 6348.0
# 55532.0
# 18312.0
# 95643.0
# The run time is --- 0.06553244590759277 seconds ---

# %%
#visualization flow allocation
vis_edge = {}
for edge_key,edge_value in edges.items():
    sum = 0
    for p in edge_value:
        sum += solution[p]
    vis_edge[edge_key]= int(sum/1000)
print(vis_edge)
# Out:
# {(8, 9): 1, (8, 3): 783, (3, 2): 7, (3, 6): 191, (6, 25): 121, (6, 1): 461, (8, 5): 9, (5, 7): 828, (5, 4): 203, (8, 13): 348, (13, 22): 455, (22, 23): 74, (13, 17): 1043, (17, 21): 175, (17, 20): 579, (17, 19): 72, (17, 18): 568, (13, 12): 1138, (13, 11): 1096, (13, 10): 308, (13, 16): 796, (13, 15): 198, (5, 14): 1200, (22, 24): 1193, (9, 8): 23, (9, 2): 184, (9, 3): 86, (2, 25): 442, (2, 6): 789, (9, 5): 45, (9, 22): 144, (2, 21): 419, (2, 20): 362, (20, 19): 72, (2, 17): 422, (9, 13): 135, (9, 16): 103, (2, 15): 240, (2, 3): 819, (3, 8): 698, (2, 9): 72, (6, 7): 881, (7, 4): 162, (17, 22): 607, (17, 13): 1200, (2, 16): 488, (3, 9): 62, (25, 6): 16, (6, 3): 747, (25, 2): 95, (25, 1): 20, (25, 7): 7, (7, 5): 514, (16, 13): 445, (1, 6): 269, (6, 2): 1200, (1, 25): 16, (5, 8): 747, (5, 9): 123, (7, 6): 700, (7, 25): 280, (5, 13): 1200, (4, 5): 18, (4, 7): 96, (22, 21): 289, (12, 24): 543, (23, 22): 160, (22, 13): 268, (13, 8): 720, (22, 9): 147, (22, 17): 188, (17, 2): 631, (13, 5): 270, (23, 24): 73, (24, 12): 647, (17, 15): 74, (10, 14): 90, (11, 14): 902, (21, 2): 519, (21, 22): 529, (21, 17): 117, (21, 18): 33, (21, 15): 35, (20, 2): 1200, (20, 17): 248, (19, 17): 38, (13, 9): 24, (19, 20): 2, (17, 16): 151, (18, 17): 958, (18, 21): 38, (12, 13): 751, (16, 2): 249, (24, 23): 11, (12, 11): 446, (11, 13): 753, (11, 12): 617, (11, 10): 24, (10, 13): 441, (10, 11): 33, (16, 9): 7, (16, 17): 25, (16, 15): 17, (15, 13): 203, (15, 2): 72, (15, 17): 13, (15, 21): 12, (15, 16): 24, (14, 5): 109, (14, 11): 255, (14, 10): 24, (24, 22): 410}

# %%
import matplotlib.pyplot as plt
pos=nx.spring_layout(DG)
# print(pos)
plt.figure()
# draw nodes
nx.draw_networkx(DG, pos, with_labels=True,node_color='yellow', font_size = 10,node_size=100, width=0.5, linewidths=1)
# draw capacities
nx.draw_networkx_edge_labels(DG, pos, edge_labels=vis_edge, font_size=7)
plt.axis('off')
plt.show()
